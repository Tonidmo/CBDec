# %%
import numpy as np
import matplotlib.pyplot as plt
import sinter

def load_data(name_file):
    data = np.loadtxt(name_file)
    # Extract columns
    p = data[:, 0]
    Pl = data[:, 1]
    return p, Pl


def error_bars(logical_error_list,):
    error_bars = []
    for Pl in logical_error_list:
        error_bar = sinter.fit_binomial(num_shots=100/Pl, num_hits=100, max_likelihood_factor=100)
        error_bars.append(error_bar)
    return error_bars
# All data points have been computed considering at least 100 logical errors.

# Load data from the file
#           BP+CB DECODING


# BB CODES
name_file = f"BBCodes/cln_BPCB_l6_m6.txt"
name_file_2 = f"BBCodes/scln_BPCB_l6_m6.txt"
name_file_3 = f"BBCodes/cln_BPOSD_l6_m6.txt"
name_file_4 = f"BBCodes/cln_CB_l6_m6.txt"

# p66, Pl66 = load_data(name_file)
# error_bars_Pl66 = error_bars(Pl66)
# sup_err_Pl = [error_bar.high for error_bar in error_bars_Pl66]
# inf_err_Pl = [error_bar.low for error_bar in error_bars_Pl66]

p66_2, Pl66_2 = load_data(name_file_2)
error_bars_Pl66_2 = error_bars(Pl66_2)
sup_err_Pl = [error_bar.high for error_bar in error_bars_Pl66_2]
inf_err_Pl = [error_bar.low for error_bar in error_bars_Pl66_2]
plt.errorbar(
    p66_2,  # X data
    Pl66_2,  # Y data
    yerr=[inf_err_Pl, sup_err_Pl],  # Lower and upper error bars
    fmt='o',  # Format for the marker
    color='red',  # Line and marker color
    markeredgecolor='black',  # Color of the marker edge
    linestyle='--',  # Line style
    label='[[72, 12, 6]] BP+BP+CB'
)

p66_2, Pl66_2 = load_data(name_file_2)
error_bars_Pl66_2 = error_bars(Pl66_2)
sup_err_Pl = [1.25*Pl for Pl in Pl66_2]
inf_err_Pl = [.8*Pl for Pl in Pl66_2]
plt.errorbar(
    p66_2,  # X data
    Pl66_2,  # Y data
    yerr=[inf_err_Pl, sup_err_Pl],  # Lower and upper error bars
    fmt='o',  # Format for the marker
    color='blue',  # Line and marker color
    markeredgecolor='black',  # Color of the marker edge
    linestyle='--',  # Line style
    label='[[72, 12, 6]] BP+BP+CB'
)


p66_2, Pl66_2 = load_data(name_file_2)
error_bars_Pl66_2 = error_bars(Pl66_2)
sup_err_Pl = [error_bar.high for error_bar in error_bars_Pl66_2]
inf_err_Pl = [error_bar.low for error_bar in error_bars_Pl66_2]
plt.errorbar(
    p66_2,  # X data
    Pl66_2,  # Y data
    yerr=[inf_err_Pl, sup_err_Pl],  # Lower and upper error bars
    fmt='o',  # Format for the marker
    color='red',  # Line and marker color
    markeredgecolor='black',  # Color of the marker edge
    linestyle='--',  # Line style
    label='[[72, 12, 6]] BP+BP+CB'
)


plt.loglog()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import sinter

def load_data(name_file):
    data = np.loadtxt(name_file)
    # Extract columns
    p = data[:, 0]
    Pl = data[:, 1]
    
    return p, Pl


def error_bars(logical_error_list):
    error_bars = []
    for Pl in logical_error_list:
        error_bar = sinter.fit_binomial(num_shots=100/Pl, num_hits=100, max_likelihood_factor=1000)
        error_bars.append(error_bar)
    return error_bars
# All data points have been computed considering at least 100 logical errors.

# Load data from the file
#           BP+CB DECODING


# BB CODES
name_file = f"BBCodes/cln_BPCB_l6_m6.txt"
name_file_2 = f"BBCodes/scln_BPCB_l6_m6.txt"
name_file_3 = f"BBCodes/cln_BPOSD_l6_m6.txt"
name_file_4 = f"BBCodes/cln_CB_l6_m6.txt"

p66, Pl66 = load_data(name_file)
p66_2, Pl66_2 = load_data(name_file_2)
error_bars_Pl66_2 = error_bars(Pl66_2)
# print(error_bars_Pl66_2)

p66_BPOSD, Pl66_BPOSD = load_data(name_file_3)
p66_CB, Pl66_CB = load_data(name_file_4)

name_file = "BBCodes/cln_BPCB_l9_m6.txt"
name_file_2 = f"BBCodes/scln_BPCB_l9_m6.txt"
name_file_3 = f"BBCodes/cln_BPOSD_l9_m6.txt"
name_file_4 = f"BBCodes/cln_CB_l9_m6.txt"
p96, Pl96 = load_data(name_file)
p96_2, Pl96_2 = load_data(name_file_2)
p96_BPOSD, Pl96_BPOSD = load_data(name_file_3)
p96_CB, Pl96_CB = load_data(name_file_4)


name_file = "BBCodes/cln_BPCB_l12_m6.txt"
name_file_2 = "BBCodes/scln_BPCB_l12_m6.txt"
name_file_3 = f"BBCodes/cln_BPOSD_l12_m6.txt"
name_file_4 = f"BBCodes/cln_CB_l12_m6.txt"
# name_file = "data_l12_m6_ng6_nb10.txt"
p126, Pl126 = load_data(name_file)
p126_2, Pl126_2 = load_data(name_file_2)
p126_BPOSD, Pl126_BPOSD = load_data(name_file_3)
p126_CB, Pl126_CB = load_data(name_file_4)

#           BP+OSD DECODING

# name_file = "bposd_data_l6_m6.txt"
# p66bposd, Pl66bposd = load_data(name_file)


# name_file = "bposd_data_l9_m6.txt"
# p96bposd, Pl96bposd = load_data(name_file)

# name_file = "bposd_data_l12_m6.txt"
# p126bposd, Pl126bposd = load_data(name_file)



from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# Plot in log-log scale
# plt.plot(p66_CB, Pl66_CB, marker='H', color = 'red', markeredgecolor='black', linestyle='-', label='[[72, 12, 6]] CB')
# plt.plot(p66, Pl66, marker='v', color = 'red', markeredgecolor='black', linestyle='-', label='[[72, 12, 6]] BP+CB')
plt.plot(p66_2[:-1], Pl66_2[:-1], marker='o', color = 'red', markeredgecolor='black', linestyle='--', label='[[72, 12, 6]] BP+BP+CB')
plt.plot(p66_BPOSD, Pl66_BPOSD, marker='D', color = 'red', markeredgecolor='black', linestyle='-', label='[[72, 12, 6]] BP+OSD')
# plt.plot(p96_CB, Pl96_CB, marker='H', color = 'green', markeredgecolor='black', linestyle='-', label='[[108, 8, 10]] CB')
# plt.plot(p96, Pl96, marker='v',color = 'green', markeredgecolor='black', linestyle='-', label='[[108, 8, 10]] BP+CB')
plt.plot(p96_2[:-1], Pl96_2[:-1], marker='o',color = 'green', markeredgecolor='black', linestyle='--', label='[[108, 8, 10]] BP+BP+CB')
plt.plot(p96_BPOSD, Pl96_BPOSD, marker='D', color = 'green', markeredgecolor='black', linestyle='-', label='[[108, 8, 10]] BP+OSD')
# plt.plot(p126_CB, Pl126_CB, marker='H', color = 'orange', markeredgecolor='black', linestyle='-', label='[[144, 12, 12]] CB')
# plt.plot(p126, Pl126, marker='v', color = 'orange', markeredgecolor='black', linestyle='-', label='[[144, 12, 12]] BP+CB')
plt.plot(p126_2, Pl126_2, marker='o', color = 'orange', markeredgecolor='black', linestyle='--', label='[[144, 12, 12]] BP+BP+CB')
plt.plot(p126_BPOSD, Pl126_BPOSD, marker='D', color = 'orange', markeredgecolor='black', linestyle='-', label='[[144, 12, 12]] BP+OSD')
plt.xlabel('$p$')
plt.ylabel('$P_L/\delta$ ')
# plt.title(f'ng = {ng}, nbr = {nbr}')
plt.xscale('log')
plt.yscale('log')

plt.title('BB Codes')
plt.legend(bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=3)
plt.margins(0.1, .1)


# 
# plt.savefig("BB_codes.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
# for element in error_bars_Pl66_2[0]:
#     print(element)
print(error_bars_Pl66_2[0].best)
# Out:
# 2.472799208704253e-06

# %%
################## Surface code ##################



name_file = f"surface_codes/cln_MX_sc_5.txt"
name_file_2 = f"surface_codes/cln_CB_sc_5.txt"
name_file_3 = f"surface_codes/cln_BPBPCB_sc_5.txt"

p_5_MX, Pl_5_MX = load_data(name_file)
p_5_CB, Pl_5_CB = load_data(name_file_2)
p_5_BPBPCB, Pl_5_BPBPCB = load_data(name_file_3)


name_file = f"surface_codes/cln_MX_sc_7.txt"
name_file_2 = f"surface_codes/cln_CB_sc_7.txt"
name_file_3 = f"surface_codes/cln_BPBPCB_sc_7.txt"

p_7_MX, Pl_7_MX = load_data(name_file)
p_7_CB, Pl_7_CB = load_data(name_file_2)
p_7_BPBPCB, Pl_7_BPBPCB = load_data(name_file_3)

name_file = f"surface_codes/cln_MX_sc_9.txt"
name_file_2 = f"surface_codes/cln_CB_sc_9.txt"
name_file_3 = f"surface_codes/cln_BPBPCB_sc_9.txt"

p_9_MX, Pl_9_MX = load_data(name_file)
p_9_CB, Pl_9_CB = load_data(name_file_2)
p_9_BPBPCB, Pl_9_BPBPCB = load_data(name_file_3)

name_file = f"surface_codes/cln_MX_sc_11.txt"
name_file_2 = f"surface_codes/cln_CB_sc_11.txt"
name_file_3 = f"surface_codes/cln_BPBPCB_sc_11.txt"


p_11_MX, Pl_11_MX = load_data(name_file)
p_11_CB, Pl_11_CB = load_data(name_file_2)
p_11_BPBPCB, Pl_11_BPBPCB = load_data(name_file_3)

# plt.plot(p_5_MX, Pl_5_MX, marker='H', color = 'red', markeredgecolor='black', linestyle='-', label='$d = 5$ MX')
plt.plot(p_5_CB, Pl_5_CB/5, marker='v', color = 'red', markeredgecolor='black', linestyle='--', label='$d = 5$ CB')
plt.plot(p_5_BPBPCB, Pl_5_BPBPCB/5, marker='D', color = 'red', markeredgecolor='black', linestyle='-.', label='$d = 5$ BP+BP+CB')

# plt.plot(p_7_MX, Pl_7_MX, marker='H', color = 'green', markeredgecolor='black', linestyle='-', label='$d = 7$ MX')
plt.plot(p_7_CB, Pl_7_CB/7, marker='v', color = 'green', markeredgecolor='black', linestyle='--', label='$d = 7$ CB')
plt.plot(p_7_BPBPCB, Pl_7_BPBPCB/7, marker='D', color = 'green', markeredgecolor='black', linestyle='-.', label='$d = 7$ BP+BP+CB')

# plt.plot(p_9_MX, Pl_9_MX, marker='H', color = 'orange', markeredgecolor='black', linestyle='-', label='$d = 9$ MX')
plt.plot(p_9_CB, Pl_9_CB/9, marker='v', color = 'orange', markeredgecolor='black', linestyle='--', label='$d = 9$ CB')
plt.plot(p_9_BPBPCB, Pl_9_BPBPCB/9, marker='D', color = 'orange', markeredgecolor='black', linestyle='-.', label='$d = 9$ BP+BP+CB')


# plt.plot(p_11_MX, Pl_11_MX, marker='H', color = 'blue', markeredgecolor='black', linestyle='-', label='$d = 11$ MX')
plt.plot(p_11_CB, Pl_11_CB/11, marker='v', color = 'blue', markeredgecolor='black', linestyle='--', label='$d = 11$ CB')
plt.plot(p_11_BPBPCB, Pl_11_BPBPCB/11, marker='D', color = 'blue', markeredgecolor='black', linestyle='-.', label='$d = 11$ BP+BP+CB')



plt.title('Surface Code')
plt.xlabel('$p$')
plt.ylabel('$P_L/\delta$')
# plt.title(f'ng = {ng}, nbr = {nbr}')
plt.xscale('log')
plt.yscale('log')


plt.legend(bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=4)
plt.margins(0.1, .1)

# 
# plt.savefig("SCode.pdf", format="pdf", bbox_inches='tight')
plt.show()

# %%
################## Color code ##################

name_file = f"cln_BPOSD_color_code_d5.txt"
# name_file_2 = f"surface_codes/cln_CB_sc_5.txt"
name_file_3 = f"cln_BPBPCB_color_code_d5.txt"
name_file_4 = "cln_BPCB_color_code_d5.txt"

p_5_BPOSD, Pl_5_BPOSD = load_data(name_file)
# p_5_CB, Pl_5_CB = load_data(name_file_2)
p_5_BPBPCB, Pl_5_BPBPCB = load_data(name_file_3)


name_file = f"cln_BPOSD_color_code_d7.txt"
# name_file_2 = f"surface_codes/cln_CB_sc_7.txt"
name_file_3 = f"cln_BPBPCB_color_code_d7.txt"
name_file_4 = "cln_BPCB_color_code_d7.txt"


p_7_BPOSD, Pl_7_BPOSD = load_data(name_file)
# p_7_CB, Pl_7_CB = load_data(name_file_2)
p_7_BPBPCB, Pl_7_BPBPCB = load_data(name_file_3)
p_7_BPCB, Pl_7_BPCB = load_data(name_file_4)

name_file = f"cln_BPOSD_color_code_d9.txt"
# name_file_2 = f"surface_codes/cln_CB_sc_7.txt"
name_file_3 = f"cln_BPBPCB_color_code_d9.txt"

p_9_BPOSD, Pl_9_BPOSD = load_data(name_file)
# p_7_CB, Pl_7_CB = load_data(name_file_2)
p_9_BPBPCB, Pl_9_BPBPCB = load_data(name_file_3)
p_9_BPCB, Pl_9_BPCB = load_data(name_file_4)

name_file = f"cln_BPOSD_color_code_d11.txt"
# name_file_2 = f"surface_codes/cln_CB_sc_7.txt"
name_file_3 = f"cln_BPBPCB_color_code_d11.txt"
name_file_4 = f"cln_BPCB_color_code_d11.txt"

p_11_BPOSD, Pl_11_BPOSD = load_data(name_file)
# p_7_CB, Pl_7_CB = load_data(name_file_2)
p_11_BPBPCB, Pl_11_BPBPCB = load_data(name_file_3)

plt.plot(p_5_BPOSD, Pl_5_BPOSD, marker='H', color = 'red', markeredgecolor='black', linestyle='-', label='$d = 5$ BPOSD')
# plt.plot(p_5_BPBPCB[:-2], Pl_5_BPBPCB[:-2], marker='D', color = 'red', markeredgecolor='black', linestyle='-.', label='$d = 5$ BP+BP+CB')

plt.plot(p_7_BPOSD, Pl_7_BPOSD, marker='H', color = 'green', markeredgecolor='black', linestyle='-', label='$d = 7$ BPOSD')
# plt.plot(p_7_BPBPCB[:-2], Pl_7_BPBPCB[:-2], marker='D', color = 'green', markeredgecolor='black', linestyle='-.', label='$d = 7$ BP+BP+CB')

plt.plot(p_9_BPOSD, Pl_9_BPOSD, marker='H', color = 'orange', markeredgecolor='black', linestyle='-', label='$d = 9$ BPOSD')
# plt.plot(p_9_BPBPCB[:-2], Pl_9_BPBPCB[:-2], marker='D', color = 'orange', markeredgecolor='black', linestyle='-.', label='$d = 9$ BP+BP+CB')


plt.plot(p_11_BPOSD, Pl_11_BPOSD, marker='H', color = 'blue', markeredgecolor='black', linestyle='-', label='$d = 11$ BPOSD')
# plt.plot(p_11_BPBPCB[:-2], Pl_11_BPBPCB[:-2], marker='D', color = 'blue', markeredgecolor='black', linestyle='-.', label='$d = 11$ BP+BP+CB')

plt.xlabel('$p$')
plt.ylabel('$P_L/\delta$')
# plt.title(f'ng = {ng}, nbr = {nbr}')
plt.xscale('log')
plt.yscale('log')

plt.title('6.6.6. Color codes')
plt.legend(bbox_to_anchor=(0.5, -0.45), loc='lower center', ncol=4)
plt.margins(0.1, .1)

# print(p_5_BPOSD)
# print(p_9_BPOSD)
# print(p_11_BPOSD)
plt.show()
